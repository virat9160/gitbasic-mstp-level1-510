# %% [markdown]
# ### Decision Tree

# %% [markdown]
# #### A desicion tree is a supervised machine learning algorthim which looks like an inverted tree,where in each node represents a predictor variable,the link between the nodes represents a desicion and each leaf node represents an outcome

# %% [markdown]
# #### ID3 Algorithm or Iterative Dichotomiser 3 algorithm----> to calculate Entropy and Information Gain

# %% [markdown]
# #### ----> Entropy: Entropy measures the impurity or uncertainty present in the data. It is used to decide how a Decision Tree can split the data
# #### Equation for Entropy:    -Ep(x)logp(x)

# %% [markdown]
# #### ---->Information Gain:Information Gain (IG) is the most significant measure used to build a Decision Tree. It indicates how much “information” a particular feature/ variable gives us about the final outcome.
# #### Equation for Information Gain: IG=entropy(parent)-[weighted average]*entropy(children)

# %%
import pandas as pd
d=[[12,13,'dog'],[10,5,'cat'],[20,25,'dog'],[13,14,'cat']]
df=pd.DataFrame(d,columns=['height','weight','pet'])

# %%
df
# Out:
#    height  weight  pet
# 0      12      13  dog
# 1      10       5  cat
# 2      20      25  dog
# 3      13      14  cat

# %%
x=df.drop('pet',axis=1)
x
# Out:
#    height  weight
# 0      12      13
# 1      10       5
# 2      20      25
# 3      13      14

# %%
y=df['pet']
y
# Out:
# 0    dog
# 1    cat
# 2    dog
# 3    cat
# Name: pet, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier()

# %%
clf.fit(x,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
clf.predict([[20,25]])
# Out:
# array(['dog'], dtype=object)

# %%
#graphviz --->generate a data in dot file
#pydotplus --->dot file into image

# %%
from sklearn.externals.six import StringIO
# Out:
# C:\Users\public\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %%
from sklearn.tree import export_graphviz

# %%
import pydotplus

# %%
from IPython.display import Image

# %%
dot_data=StringIO()

# %%
export_graphviz(clf,out_file=dot_data,filled=True,rounded=True,feature_names=x.columns,class_names=['cat','dog'])

# %%
graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
graph

# %%
Image(graph.create_png())

# %%
zoo=pd.read_csv('zoo.csv')

# %%
zoo.head()
# Out:
#   animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0    aardvark     1         0     0     1         0        0         1
# 1    antelope     1         0     0     1         0        0         0
# 2        bass     0         0     1     0         0        1         1
# 3        bear     1         0     0     1         0        0         1
# 4        boar     1         0     0     1         0        0         1
#
#    toothed  backbone  breathes  venomous  fins  legs  tail  domestic  catsize  \
# 0        1         1         1         0     0     4     0         0        1
# 1        1         1         1         0     0     4     1         0        1
# 2        1         1         0         0     1     0     1         0        0
# 3        1         1         1         0     0     4     0         0        1
# 4        1         1         1         0     0     4     1         0        1
#
#    class_type
# 0           1
# 1           1
# 2           4
# 3           1
# 4           1

# %%
zoo['class_type'].unique()
# Out:
# array([1, 4, 2, 7, 6, 5, 3], dtype=int64)

# %%
animalname=pd.read_csv('class.csv')
animalname
# Out:
#    Class_Number  Number_Of_Animal_Species_In_Class    Class_Type  \
# 0             1                                 41        Mammal
# 1             2                                 20          Bird
# 2             3                                  5       Reptile
# 3             4                                 13          Fish
# 4             5                                  4     Amphibian
# 5             6                                  8           Bug
# 6             7                                 10  Invertebrate
#
#                                         Animal_Names
# 0  aardvark, antelope, bear, boar, buffalo, calf,...
# 1  chicken, crow, dove, duck, flamingo, gull, haw...
# 2    pitviper, seasnake, slowworm, tortoise, tuatara
# 3  bass, carp, catfish, chub, dogfish, haddock, h...
# 4                             frog, frog, newt, toad
# 5  flea, gnat, honeybee, housefly, ladybird, moth...
# 6  clam, crab, crayfish, lobster, octopus, scorpi...

# %%
animal_df=pd.merge(zoo,animalname,how='left',left_on='class_type',right_on='Class_Number')

# %%
animal_df
# Out:
#     animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0      aardvark     1         0     0     1         0        0         1
# 1      antelope     1         0     0     1         0        0         0
# 2          bass     0         0     1     0         0        1         1
# 3          bear     1         0     0     1         0        0         1
# 4          boar     1         0     0     1         0        0         1
# 5       buffalo     1         0     0     1         0        0         0
# 6          calf     1         0     0     1         0        0         0
# 7          carp     0         0     1     0         0        1         0
# 8       catfish     0         0     1     0         0        1         1
# 9          cavy     1         0     0     1         0        0         0
# 10      cheetah     1         0     0     1         0        0         1
# 11      chicken     0         1     1     0         1        0         0
# 12         chub     0         0     1     0         0        1         1
# 13         clam     0         0     1     0         0        0         1
# 14         crab     0         0     1     0         0        1         1
# 15     crayfish     0         0     1     0         0        1         1
# 16         crow     0         1     1     0         1        0         1
# 17         deer     1         0     0     1         0        0         0
# 18      dogfish     0         0     1     0         0        1         1
# 19      dolphin     0         0     0     1         0        1         1
# 20         dove     0         1     1     0         1        0         0
# 21         duck     0         1     1     0         1        1         0
# 22     elephant     1         0     0     1         0        0         0
# 23     flamingo     0         1     1     0         1        0         0
# 24         flea     0         0     1     0         0        0         0
# 25         frog     0         0     1     0         0        1         1
# 26         frog     0         0     1     0         0        1         1
# 27     fruitbat     1         0     0     1         1        0         0
# 28      giraffe     1         0     0     1         0        0         0
# 29         girl     1         0     0     1         0        0         1
# ..          ...   ...       ...   ...   ...       ...      ...       ...
# 71         rhea     0         1     1     0         0        0         1
# 72     scorpion     0         0     0     0         0        0         1
# 73     seahorse     0         0     1     0         0        1         0
# 74         seal     1         0     0     1         0        1         1
# 75      sealion     1         0     0     1         0        1         1
# 76     seasnake     0         0     0     0         0        1         1
# 77      seawasp     0         0     1     0         0        1         1
# 78      skimmer     0         1     1     0         1        1         1
# 79         skua     0         1     1     0         1        1         1
# 80     slowworm     0         0     1     0         0        0         1
# 81         slug     0         0     1     0         0        0         0
# 82         sole     0         0     1     0         0        1         0
# 83      sparrow     0         1     1     0         1        0         0
# 84     squirrel     1         0     0     1         0        0         0
# 85     starfish     0         0     1     0         0        1         1
# 86     stingray     0         0     1     0         0        1         1
# 87         swan     0         1     1     0         1        1         0
# 88      termite     0         0     1     0         0        0         0
# 89         toad     0         0     1     0         0        1         0
# 90     tortoise     0         0     1     0         0        0         0
# 91      tuatara     0         0     1     0         0        0         1
# 92         tuna     0         0     1     0         0        1         1
# 93      vampire     1         0     0     1         1        0         0
# 94         vole     1         0     0     1         0        0         0
# 95      vulture     0         1     1     0         1        0         1
# 96      wallaby     1         0     0     1         0        0         0
# 97         wasp     1         0     1     0         1        0         0
# 98         wolf     1         0     0     1         0        0         1
# 99         worm     0         0     1     0         0        0         0
# 100        wren     0         1     1     0         1        0         0
#
#      toothed  backbone  ...  fins  legs  tail  domestic  catsize  class_type  \
# 0          1         1  ...     0     4     0         0        1           1
# 1          1         1  ...     0     4     1         0        1           1
# 2          1         1  ...     1     0     1         0        0           4
# 3          1         1  ...     0     4     0         0        1           1
# 4          1         1  ...     0     4     1         0        1           1
# 5          1         1  ...     0     4     1         0        1           1
# 6          1         1  ...     0     4     1         1        1           1
# 7          1         1  ...     1     0     1         1        0           4
# 8          1         1  ...     1     0     1         0        0           4
# 9          1         1  ...     0     4     0         1        0           1
# 10         1         1  ...     0     4     1         0        1           1
# 11         0         1  ...     0     2     1         1        0           2
# 12         1         1  ...     1     0     1         0        0           4
# 13         0         0  ...     0     0     0         0        0           7
# 14         0         0  ...     0     4     0         0        0           7
# 15         0         0  ...     0     6     0         0        0           7
# 16         0         1  ...     0     2     1         0        0           2
# 17         1         1  ...     0     4     1         0        1           1
# 18         1         1  ...     1     0     1         0        1           4
# 19         1         1  ...     1     0     1         0        1           1
# 20         0         1  ...     0     2     1         1        0           2
# 21         0         1  ...     0     2     1         0        0           2
# 22         1         1  ...     0     4     1         0        1           1
# 23         0         1  ...     0     2     1         0        1           2
# 24         0         0  ...     0     6     0         0        0           6
# 25         1         1  ...     0     4     0         0        0           5
# 26         1         1  ...     0     4     0         0        0           5
# 27         1         1  ...     0     2     1         0        0           1
# 28         1         1  ...     0     4     1         0        1           1
# 29         1         1  ...     0     2     0         1        1           1
# ..       ...       ...  ...   ...   ...   ...       ...      ...         ...
# 71         0         1  ...     0     2     1         0        1           2
# 72         0         0  ...     0     8     1         0        0           7
# 73         1         1  ...     1     0     1         0        0           4
# 74         1         1  ...     1     0     0         0        1           1
# 75         1         1  ...     1     2     1         0        1           1
# 76         1         1  ...     0     0     1         0        0           3
# 77         0         0  ...     0     0     0         0        0           7
# 78         0         1  ...     0     2     1         0        0           2
# 79         0         1  ...     0     2     1         0        0           2
# 80         1         1  ...     0     0     1         0        0           3
# 81         0         0  ...     0     0     0         0        0           7
# 82         1         1  ...     1     0     1         0        0           4
# 83         0         1  ...     0     2     1         0        0           2
# 84         1         1  ...     0     2     1         0        0           1
# 85         0         0  ...     0     5     0         0        0           7
# 86         1         1  ...     1     0     1         0        1           4
# 87         0         1  ...     0     2     1         0        1           2
# 88         0         0  ...     0     6     0         0        0           6
# 89         1         1  ...     0     4     0         0        0           5
# 90         0         1  ...     0     4     1         0        1           3
# 91         1         1  ...     0     4     1         0        0           3
# 92         1         1  ...     1     0     1         0        1           4
# 93         1         1  ...     0     2     1         0        0           1
# 94         1         1  ...     0     4     1         0        0           1
# 95         0         1  ...     0     2     1         0        1           2
# 96         1         1  ...     0     2     1         0        1           1
# 97         0         0  ...     0     6     0         0        0           6
# 98         1         1  ...     0     4     1         0        1           1
# 99         0         0  ...     0     0     0         0        0           7
# 100        0         1  ...     0     2     1         0        0           2
#
#      Class_Number  Number_Of_Animal_Species_In_Class    Class_Type  \
# 0               1                                 41        Mammal
# 1               1                                 41        Mammal
# 2               4                                 13          Fish
# 3               1                                 41        Mammal
# 4               1                                 41        Mammal
# 5               1                                 41        Mammal
# 6               1                                 41        Mammal
# 7               4                                 13          Fish
# 8               4                                 13          Fish
# 9               1                                 41        Mammal
# 10              1                                 41        Mammal
# 11              2                                 20          Bird
# 12              4                                 13          Fish
# 13              7                                 10  Invertebrate
# 14              7                                 10  Invertebrate
# 15              7                                 10  Invertebrate
# 16              2                                 20          Bird
# 17              1                                 41        Mammal
# 18              4                                 13          Fish
# 19              1                                 41        Mammal
# 20              2                                 20          Bird
# 21              2                                 20          Bird
# 22              1                                 41        Mammal
# 23              2                                 20          Bird
# 24              6                                  8           Bug
# 25              5                                  4     Amphibian
# 26              5                                  4     Amphibian
# 27              1                                 41        Mammal
# 28              1                                 41        Mammal
# 29              1                                 41        Mammal
# ..            ...                                ...           ...
# 71              2                                 20          Bird
# 72              7                                 10  Invertebrate
# 73              4                                 13          Fish
# 74              1                                 41        Mammal
# 75              1                                 41        Mammal
# 76              3                                  5       Reptile
# 77              7                                 10  Invertebrate
# 78              2                                 20          Bird
# 79              2                                 20          Bird
# 80              3                                  5       Reptile
# 81              7                                 10  Invertebrate
# 82              4                                 13          Fish
# 83              2                                 20          Bird
# 84              1                                 41        Mammal
# 85              7                                 10  Invertebrate
# 86              4                                 13          Fish
# 87              2                                 20          Bird
# 88              6                                  8           Bug
# 89              5                                  4     Amphibian
# 90              3                                  5       Reptile
# 91              3                                  5       Reptile
# 92              4                                 13          Fish
# 93              1                                 41        Mammal
# 94              1                                 41        Mammal
# 95              2                                 20          Bird
# 96              1                                 41        Mammal
# 97              6                                  8           Bug
# 98              1                                 41        Mammal
# 99              7                                 10  Invertebrate
# 100             2                                 20          Bird
#
#                                           Animal_Names
# 0    aardvark, antelope, bear, boar, buffalo, calf,...
# 1    aardvark, antelope, bear, boar, buffalo, calf,...
# 2    bass, carp, catfish, chub, dogfish, haddock, h...
# 3    aardvark, antelope, bear, boar, buffalo, calf,...
# 4    aardvark, antelope, bear, boar, buffalo, calf,...
# 5    aardvark, antelope, bear, boar, buffalo, calf,...
# 6    aardvark, antelope, bear, boar, buffalo, calf,...
# 7    bass, carp, catfish, chub, dogfish, haddock, h...
# 8    bass, carp, catfish, chub, dogfish, haddock, h...
# 9    aardvark, antelope, bear, boar, buffalo, calf,...
# 10   aardvark, antelope, bear, boar, buffalo, calf,...
# 11   chicken, crow, dove, duck, flamingo, gull, haw...
# 12   bass, carp, catfish, chub, dogfish, haddock, h...
# 13   clam, crab, crayfish, lobster, octopus, scorpi...
# 14   clam, crab, crayfish, lobster, octopus, scorpi...
# 15   clam, crab, crayfish, lobster, octopus, scorpi...
# 16   chicken, crow, dove, duck, flamingo, gull, haw...
# 17   aardvark, antelope, bear, boar, buffalo, calf,...
# 18   bass, carp, catfish, chub, dogfish, haddock, h...
# 19   aardvark, antelope, bear, boar, buffalo, calf,...
# 20   chicken, crow, dove, duck, flamingo, gull, haw...
# 21   chicken, crow, dove, duck, flamingo, gull, haw...
# 22   aardvark, antelope, bear, boar, buffalo, calf,...
# 23   chicken, crow, dove, duck, flamingo, gull, haw...
# 24   flea, gnat, honeybee, housefly, ladybird, moth...
# 25                              frog, frog, newt, toad
# 26                              frog, frog, newt, toad
# 27   aardvark, antelope, bear, boar, buffalo, calf,...
# 28   aardvark, antelope, bear, boar, buffalo, calf,...
# 29   aardvark, antelope, bear, boar, buffalo, calf,...
# ..                                                 ...
# 71   chicken, crow, dove, duck, flamingo, gull, haw...
# 72   clam, crab, crayfish, lobster, octopus, scorpi...
# 73   bass, carp, catfish, chub, dogfish, haddock, h...
# 74   aardvark, antelope, bear, boar, buffalo, calf,...
# 75   aardvark, antelope, bear, boar, buffalo, calf,...
# 76     pitviper, seasnake, slowworm, tortoise, tuatara
# 77   clam, crab, crayfish, lobster, octopus, scorpi...
# 78   chicken, crow, dove, duck, flamingo, gull, haw...
# 79   chicken, crow, dove, duck, flamingo, gull, haw...
# 80     pitviper, seasnake, slowworm, tortoise, tuatara
# 81   clam, crab, crayfish, lobster, octopus, scorpi...
# 82   bass, carp, catfish, chub, dogfish, haddock, h...
# 83   chicken, crow, dove, duck, flamingo, gull, haw...
# 84   aardvark, antelope, bear, boar, buffalo, calf,...
# 85   clam, crab, crayfish, lobster, octopus, scorpi...
# 86   bass, carp, catfish, chub, dogfish, haddock, h...
# 87   chicken, crow, dove, duck, flamingo, gull, haw...
# 88   flea, gnat, honeybee, housefly, ladybird, moth...
# 89                              frog, frog, newt, toad
# 90     pitviper, seasnake, slowworm, tortoise, tuatara
# 91     pitviper, seasnake, slowworm, tortoise, tuatara
# 92   bass, carp, catfish, chub, dogfish, haddock, h...
# 93   aardvark, antelope, bear, boar, buffalo, calf,...
# 94   aardvark, antelope, bear, boar, buffalo, calf,...
# 95   chicken, crow, dove, duck, flamingo, gull, haw...
# 96   aardvark, antelope, bear, boar, buffalo, calf,...
# 97   flea, gnat, honeybee, housefly, ladybird, moth...
# 98   aardvark, antelope, bear, boar, buffalo, calf,...
# 99   clam, crab, crayfish, lobster, octopus, scorpi...
# 100  chicken, crow, dove, duck, flamingo, gull, haw...
#
# [101 rows x 22 columns]
